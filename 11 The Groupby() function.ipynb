# %%
import numpy as np

# %%
import pandas as pd

# %%
company=pd.read_csv('Fortune 500 Companies US.csv', encoding='latin1')
company
# Out:
#      Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0       1             Walmart           23,00,000            1.0  $4,85,873
# 1       2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2       3               Apple            1,16,000            3.0  $2,15,639
# 3       4         Exxon Mobil              72,700            2.0  $2,05,004
# 4       5            McKesson              68,000            5.0  $1,92,487
# ..    ...                 ...                 ...            ...        ...
# 495   496       Michaels Cos.              31,000          517.0     $5,197
# 496   497       Toll Brothers               4,200          576.0     $5,170
# 497   498               Yahoo               8,500          513.0     $5,169
# 498   499       Vistra Energy               4,431            NaN     $5,164
# 499   500      ABM Industries            1,10,000          485.0     $5,145
#
# ...

# %%
company=pd.read_csv('Fortune 500 Companies US.csv', encoding='latin1')
company.head()
# Out:
#    Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0     1             Walmart           23,00,000            1.0  $4,85,873
# 1     2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2     3               Apple            1,16,000            3.0  $2,15,639
# 3     4         Exxon Mobil              72,700            2.0  $2,05,004
# 4     5            McKesson              68,000            5.0  $1,92,487
#
#   Revenue Change    Profits Profit Change     Assets Market Value
# 0           0.8%  $13,643.0         -7.2%  $1,98,825    $2,18,619
# 1           6.1%  $24,074.0          0.0%  $6,20,854    $4,11,035
# 2          -7.7%  $45,687.0        -14.4%  $3,21,686    $7,53,718
# 3         -16.7%   $7,840.0        -51.5%  $3,30,314    $3,40,056
# 4           6.2%   $2,258.0         53.0%    $56,563      $31,439

# %%
company=pd.read_csv('Fortune 500 Companies US.csv', encoding='latin1')
company.head(2)
# Out:
#    Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0     1             Walmart           23,00,000            1.0  $4,85,873
# 1     2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
#
#   Revenue Change    Profits Profit Change     Assets Market Value
# 0           0.8%  $13,643.0         -7.2%  $1,98,825    $2,18,619
# 1           6.1%  $24,074.0          0.0%  $6,20,854    $4,11,035

# %%
a=company.groupby('Number of Employees')
a

# %%
len(company)
# Out:
# 500

# %%
len('Number of Employees')
# Out:
# 19

# %%
a.size()
# Out:
# Number of Employees
# 1,00,300    1
# 1,03,500    1
# 1,05,000    1
# 1,06,000    2
# 1,08,000    1
#            ..
# 93,000      1
# 95,400      1
# 96,500      1
# 97,000      1
# 98,800      1
# Length: 399, dtype: int64

# %%
a.size().sort_values(ascending=False)
# Out:
# Number of Employees
# 25,000      6
# 14,000      6
# 50,000      4
# 20,000      4
# 21,000      4
#            ..
# 2,95,000    1
# 2,74,000    1
# 2,69,100    1
# 2,68,540    1
# 98,800      1
# Length: 399, dtype: int64

# %%
a.first()
# Out:
#                      Rank              Company Name  Previous Rank Revenues  \
# Number of Employees
# 1,00,300               64                 Coca-Cola           62.0  $41,863
# 1,03,500              139          Emerson Electric          128.0  $20,268
# 1,05,000               36          Procter & Gamble           34.0  $71,726
# 1,06,000               47                     Intel           51.0  $59,387
# 1,08,000              130  Community Health Systems          125.0  $21,374
# ...                   ...                       ...            ...      ...
# 93,000                137                 Whirlpool          134.0  $20,718
# 95,400                 74               Caterpillar           59.0  $38,537
# 96,500                 54                    Pfizer           55.0  $52,824
# 97,000                 56           Lockheed Martin           60.0  $50,658
# 98,800                 90          General Dynamics           88.0  $31,353
#
# ...

# %%
a.last()
# Out:
#                      Rank              Company Name  Previous Rank Revenues  \
# Number of Employees
# 1,00,300               64                 Coca-Cola           62.0  $41,863
# 1,03,500              139          Emerson Electric          128.0  $20,268
# 1,05,000               36          Procter & Gamble           34.0  $71,726
# 1,06,000              221               J.C. Penney          228.0  $12,547
# 1,08,000              130  Community Health Systems          125.0  $21,374
# ...                   ...                       ...            ...      ...
# 93,000                137                 Whirlpool          134.0  $20,718
# 95,400                 74               Caterpillar           59.0  $38,537
# 96,500                 54                    Pfizer           55.0  $52,824
# 97,000                 56           Lockheed Martin           60.0  $50,658
# 98,800                 90          General Dynamics           88.0  $31,353
#
# ...

# %%
a.groups
# Out:
# {'1,00,300': [63], '1,03,500': [138], '1,05,000': [35], '1,06,000': [46, 220], '1,08,000': [129], '1,10,000': [197, 499], '1,14,000': [27, 81], '1,16,000': [2], '1,16,050': [135], '1,16,475': [133], '1,21,000': [127], '1,22,300': [66], '1,25,000': [71], '1,26,400': [34], '1,31,000': [72], '1,326': [479], '1,33,600': [161], '1,35,000': [177], '1,36,000': [80], '1,38,000': [40, 151], '1,40,000': [126], '1,464': [188], '1,48,300': [109], '1,48,400': [150], '1,50,540': [23], '1,50,942': [384], '1,59,000': [30], '1,60,900': [13], '1,69,000': [240], '1,72,000': [15], '1,770': [333], '1,91,000': [84], '1,95,000': [51, 58], '1,970': [401], '10,000': [208, 271], '10,212': [125], '10,299': [386], '10,400': [340], '10,471': [314], '10,700': [477], '10,900': [459], '11,000': [277, 455, 464], '11,121': [214], '11,170': [317], '11,300': [336], '11,320': [64], '11,476': [255], '11,500': [329, 349], '11,737': [76], '11,781': [485], '11,800': [447], '11,870': [484], '11,900': [266, 468], '12,030': [4
# ...

# %%
a.groups

company.iloc[23,:]
# Out:
# Rank                          24
# Company Name              Boeing
# Number of Employees     1,50,540
# Previous Rank               24.0
# Revenues                 $94,571
# Revenue Change             -1.6%
# Profits                 $4,895.0
# Profit Change              -5.4%
# Assets                   $89,997
# Market Value           $1,07,546
# Name: 23, dtype: object

# %%
a.get_group('23,00,000')
# Out:
#    Rank Company Name Number of Employees  Previous Rank   Revenues  \
# 0     1      Walmart           23,00,000            1.0  $4,85,873
#
#   Revenue Change    Profits Profit Change     Assets Market Value
# 0           0.8%  $13,643.0         -7.2%  $1,98,825    $2,18,619

# %%
a.get_group('23,00,000').shape
# Out:
# (1, 10)

# %%
a.sum()
# Out:
#                      Rank              Company Name  Previous Rank  \
# Number of Employees
# 1,00,300               64                 Coca-Cola           62.0
# 1,03,500              139          Emerson Electric          128.0
# 1,05,000               36          Procter & Gamble           34.0
# 1,06,000              268          IntelJ.C. Penney          279.0
# 1,08,000              130  Community Health Systems          125.0
# ...                   ...                       ...            ...
# 93,000                137                 Whirlpool          134.0
# 95,400                 74               Caterpillar           59.0
# 96,500                 54                    Pfizer           55.0
# 97,000                 56           Lockheed Martin           60.0
# 98,800                 90          General Dynamics           88.0
#
#                            Revenues Revenue Change        Profits  \
# Number of Employees
# ...

# %%
a.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...
